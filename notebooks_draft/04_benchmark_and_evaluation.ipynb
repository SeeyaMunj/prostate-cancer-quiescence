# %% [markdown]
# # 4. Method benchmark and the evaluation classifierTrains every method on the same full training matrix, takes each method's own top-10 genes, and scores all of them with the same evaluation classifier. Produces the numbers in Supplementary Table S3.**Inputs:** normalized matrices, `results/common_genes.txt`**Outputs:** `results/<dataset>/fold_*_cpu_scores.npz`, `results/<dataset>/fold_*_cpu_topgenes.json`**Approximate runtime:** about 20-40 minutes per dataset (random forest and XGBoost dominate)Paths are set in `scripts/common.py` (`H5_DIR`, `RAW_DIR`, `OUT`). Edit them once before running any notebook.

# %%
import sys, jsonfrom pathlib import Pathsys.path.insert(0, str(Path.cwd().parent / 'scripts'))import common as Cprint('datasets:', list(C.DATASETS))print('results directory:', C.OUT)

# %%
# %run ../scripts/ribo_ablation.py --help

# %% [markdown]
# Run the benchmark for one dataset:

# %%
# !python ../scripts/ribo_ablation.py --part cpu --dataset PC3_high

# %% [markdown]
# Collect the results into the table:

# %%
# !python ../scripts/eval_top10_table.py
