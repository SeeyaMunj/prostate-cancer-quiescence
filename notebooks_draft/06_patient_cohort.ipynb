# %% [markdown]
# # 6. Patient cohort analysis (GSE176031)Reproduces Supplementary Table S1 and Supplementary Figure S8: the fold-change-weighted 26-gene score in the tumor-enriched luminal epithelium of GSE176031, its association with three proliferation measures, the per-patient summary and the unweighted sensitivity analysis. This step runs in R.**Inputs:** `gse176031_tumor_epithelial_scored.rds`, `PC3LOW_26GENES.csv`**Outputs:** `results_comment7/comment7_patient_association_results.csv`, `FigureS8_weighted_G0_score.png`**Approximate runtime:** about 3 minutesPaths are set in `scripts/common.py` (`H5_DIR`, `RAW_DIR`, `OUT`). Edit them once before running any notebook.

# %% [markdown]
# ```bashRscript ../scripts/comment7_patient_analysis.R```Edit the three paths at the top of the script first (`IN_RDS`, `IN_FC`, `OUT_DIR`).

# %%
import pandas as pdres = pd.read_csv('../results_comment7/comment7_patient_association_results.csv')res[['score','measure','cell_rho','cell_p','mixed_beta','mixed_p']]
